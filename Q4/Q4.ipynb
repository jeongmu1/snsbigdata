# %%
import os
import re
import time
import requests
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.chrome.service import Service


def search_google(query, num_results):
    options = webdriver.ChromeOptions()
    options.add_argument('--headless')
    options.add_argument('--disable-gpu')
    options.add_argument('--no-sandbox')
    options.add_argument('--disable-dev-shm-usage')
    driver = webdriver.Chrome(service= Service(ChromeDriverManager().install()))

    query = query.replace(' ', '+') + '+filetype:pdf'
    url = f"https://www.google.com/search?q={query}&num={num_results}"
    driver.get(url)
    
    last_height = driver.execute_script("return document.body.scrollHeight")
    
    while True:
        driver.find_element(By.TAG_NAME, "body").send_keys(Keys.END)
        time.sleep(2)
        
        new_height = driver.execute_script("return document.body.scrollHeight")
        if new_height == last_height:
            break
        last_height = new_height

    html = driver.page_source
    driver.quit()
    return html

def extract_pdf_links(html):
    soup = BeautifulSoup(html, 'html.parser')
    links = []
    for a_tag in soup.find_all('a', href=True):
        href = a_tag['href']
        if re.search(r'\.pdf$', href):
            links.append(href)
        elif '/url?q=' in href:
            parsed_url = urllib.parse.parse_qs(urllib.parse.urlparse(href).query).get('q')
            if parsed_url and re.search(r'\.pdf$', parsed_url[0]):
                links.append(parsed_url[0])
    return links

def download_pdf(url, output_path):
    response = requests.get(url)
    response.raise_for_status()
    with open(output_path, 'wb') as file:
        file.write(response.content)

def main():
    query = input("검색어를 입력하세요: ")
    num_files = int(input("다운로드할 파일 개수를 입력하세요: "))
    save_directory = "/Users/gangjeongmu/temp/Q4"

    html = search_google(query, num_files)
    pdf_links = extract_pdf_links(html)

    if not pdf_links:
        print("PDF 링크를 찾을 수 없습니다.")
        return

    for i, pdf_link in enumerate(pdf_links[:num_files]):
        output_path = os.path.join(save_directory, f"document_{i+1}.pdf")
        print(f"Downloading {pdf_link} to {output_path}")
        try:
            download_pdf(pdf_link, output_path)
            print(f"Downloaded {pdf_link} to {output_path}")
        except Exception as e:
            print(f"Failed to download {pdf_link}: {e}")

if __name__ == "__main__":
    main()
# Out:
# 검색어를 입력하세요: ufc
# 다운로드할 파일 개수를 입력하세요: 10
# 파일을 저장할 위치를 입력하세요: /Users/gangjeongmu/temp/Q4
# Downloading https://media.ufc.tv/ufcpi/UFCPI_Book_2018.pdf to /Users/gangjeongmu/temp/Q4/document_1.pdf
# Downloaded https://media.ufc.tv/ufcpi/UFCPI_Book_2018.pdf to /Users/gangjeongmu/temp/Q4/document_1.pdf
# Downloading https://media.ufc.tv/ufcpi/UFCPI_Book_2018.pdf to /Users/gangjeongmu/temp/Q4/document_2.pdf
# Downloaded https://media.ufc.tv/ufcpi/UFCPI_Book_2018.pdf to /Users/gangjeongmu/temp/Q4/document_2.pdf
# Downloading https://media.ufc.tv/ufcpi/UFCPI_Book_2018.pdf to /Users/gangjeongmu/temp/Q4/document_3.pdf
# Downloaded https://media.ufc.tv/ufcpi/UFCPI_Book_2018.pdf to /Users/gangjeongmu/temp/Q4/document_3.pdf
# Downloading https://www.wbdg.org/FFC/DOD/UFC/ufc_3_530_01_2023_c1.pdf to /Users/gangjeongmu/temp/Q4/document_4.pdf
# Downloaded https://www.wbdg.org/FFC/DOD/UFC/ufc_3_530_01_2023_c1.pdf to /Users/gangjeongmu/temp/Q4/document_4.pdf
# Downloading https://www.cdse.edu/Portals/124/Documents/jobaids/physical/UFC-4-022-01Security-Enginering-Entry-Control-Facilities-Access-Points.pdf to /Users/gangjeongmu/temp/Q4/document_5.pdf
# Downloaded https://www.cdse.edu/Portals/124/Documents/jobaids/physical/UFC-4-022-01Security-Enginering-Entry-Control-Facilities-Access-Points.pdf to /Users/gangjeongmu/temp/Q4/document_5.pdf
# Downloading https://media.ufc.tv/ufcpi/UFCPI_Book_2018.pdf to /Users/gangjeongmu/temp/Q4/document_6.pdf
# Downloaded https://media.ufc.tv/ufcpi/UFCPI_Book_2018.pdf to /Users/gangjeongmu/temp/Q4/document_6.pdf
# Downloading https://www.wbdg.org/FFC/DOD/UFC/ufc_4_141_10_2022.pdf to /Users/gangjeongmu/temp/Q4/document_7.pdf
# Downloaded https://www.wbdg.org/FFC/DOD/UFC/ufc_4_141_10_2022.pdf to /Users/gangjeongmu/temp/Q4/document_7.pdf
# Downloading https://media.ufc.tv/ufcpi/UFCPI_Book_2018.pdf to /Users/gangjeongmu/temp/Q4/document_8.pdf
# Downloaded https://media.ufc.tv/ufcpi/UFCPI_Book_2018.pdf to /Users/gangjeongmu/temp/Q4/document_8.pdf
# Downloading https://media.ufc.tv/ufcpi/UFCPI_Book_2018.pdf to /Users/gangjeongmu/temp/Q4/document_9.pdf
# Downloaded https://media.ufc.tv/ufcpi/UFCPI_Book_2018.pdf to /Users/gangjeongmu/temp/Q4/document_9.pdf
# Downloading https://investor.tkogrp.com/files/doc_downloads/2023/10/UFC_Saudi-Fight-Night-Release_10-11-23_FINAL.pdf to /Users/gangjeongmu/temp/Q4/document_10.pdf
# Failed to download https://investor.tkogrp.com/files/doc_downloads/2023/10/UFC_Saudi-Fight-Night-Release_10-11-23_FINAL.pdf: 403 Client Error: Forbidden for url: https://investor.tkogrp.com/files/doc_downloads/2023/10/UFC_Saudi-Fight-Night-Release_10-11-23_FINAL.pdf
